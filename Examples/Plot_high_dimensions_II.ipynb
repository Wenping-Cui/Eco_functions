# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Explore-Community-augmentation,-Rejection-failure,-Indirect-failure,-Replacement-in-steady-state" data-toc-modified-id="Explore-Community-augmentation,-Rejection-failure,-Indirect-failure,-Replacement-in-steady-state-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Explore Community augmentation, Rejection failure, Indirect failure, Replacement in steady state</a></span><ul class="toc-item"><li><span><a href="#Typical-steady-state" data-toc-modified-id="Typical-steady-state-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Typical steady state</a></span><ul class="toc-item"><li><span><a href="#load-all-the-data" data-toc-modified-id="load-all-the-data-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>load all the data</a></span></li><li><span><a href="#Richness-in-different-types-of-resource-dynamics." data-toc-modified-id="Richness-in-different-types-of-resource-dynamics.-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Richness in different types of resource dynamics.</a></span></li><li><span><a href="#Mean-and-vaiance-richness-at-differnt-invasion-steps" data-toc-modified-id="Mean-and-vaiance-richness-at-differnt-invasion-steps-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Mean and vaiance richness at differnt invasion steps</a></span></li><li><span><a href="#Richness-and-Consumed-Power" data-toc-modified-id="Richness-and-Consumed-Power-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Richness and Consumed Power</a></span></li><li><span><a href="#Steps-and-Consumed-Power" data-toc-modified-id="Steps-and-Consumed-Power-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Steps and Consumed Power</a></span></li><li><span><a href="#Community-augmentation,-richness-and-consumed-power" data-toc-modified-id="Community-augmentation,-richness-and-consumed-power-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Community augmentation, richness and consumed power</a></span></li><li><span><a href="#Community-augmentaion-and-consumed-power" data-toc-modified-id="Community-augmentaion-and-consumed-power-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>Community augmentaion and consumed power</a></span></li></ul></li><li><span><a href="#Large-maintance-costs(10-times-larger)" data-toc-modified-id="Large-maintance-costs(10-times-larger)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Large maintance costs(10 times larger)</a></span><ul class="toc-item"><li><span><a href="#Richness-and-Consumed-Power" data-toc-modified-id="Richness-and-Consumed-Power-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Richness and Consumed Power</a></span></li></ul></li><li><span><a href="#Large-niche-overlap" data-toc-modified-id="Large-niche-overlap-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Large niche overlap</a></span><ul class="toc-item"><li><span><a href="#Community-augmentation,-richness-and-consumed-power" data-toc-modified-id="Community-augmentation,-richness-and-consumed-power-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Community augmentation, richness and consumed power</a></span></li><li><span><a href="#Community-augmentation,-step-and-consumed-power" data-toc-modified-id="Community-augmentation,-step-and-consumed-power-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Community augmentation, step and consumed power</a></span></li></ul></li><li><span><a href="#Large-steps" data-toc-modified-id="Large-steps-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Large steps</a></span><ul class="toc-item"><li><span><a href="#Community-augmentation,-richness-and-consumed-power" data-toc-modified-id="Community-augmentation,-richness-and-consumed-power-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Community augmentation, richness and consumed power</a></span></li><li><span><a href="#Community-augmentation,-step-and-consumed-power" data-toc-modified-id="Community-augmentation,-step-and-consumed-power-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Community augmentation, step and consumed power</a></span></li><li><span><a href="#Richness-distribution" data-toc-modified-id="Richness-distribution-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Richness distribution</a></span></li><li><span><a href="#Mean-and-vaiance-richness-at-differnt-invasion-steps" data-toc-modified-id="Mean-and-vaiance-richness-at-differnt-invasion-steps-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Mean and vaiance richness at differnt invasion steps</a></span></li><li><span><a href="#Richness-and-Consumed-Power" data-toc-modified-id="Richness-and-Consumed-Power-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Richness and Consumed Power</a></span></li><li><span><a href="#Steps-and-Consumed-Power" data-toc-modified-id="Steps-and-Consumed-Power-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Steps and Consumed Power</a></span></li></ul></li></ul></li></ul></div>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import time
import re
import pandas as pd
import matplotlib
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np
from Eco_function.eco_lib import *
from Eco_function.eco_plot import *
from Eco_function.eco_func import *
import pdb
import os.path
import pickle
from scipy.integrate import odeint
from scipy.signal import savgol_filter
import seaborn as sns
from tqdm import tqdm
sns.set(style="white")
tableau20=color20() # initial colors for plot;

# %% [markdown]
# # Explore Community augmentation, Rejection failure, Indirect failure, Replacement in steady state
# * Community augmentation: the invasion is successful and the community’s richness is increased by one.
# * Rejection failure: the invasive specie failed and the resident community stay the same.
# * Indirect failure: the invasive specie failed but the species or resource abundance is changed.
# * Replacement: the invasion is successful and one or more resident species extinct.
# ## Typical steady state
# ### load all the data

# %%
Initial_type='steady_initial'
data_Community_augmentation='simulation_data/Richness_augmentation_p0.1_2018_04_16-13-52_correction.csv'
data_name=data_Community_augmentation
Model_plot=Invasion_plot([data_name])
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# ### Richness in different types of resource dynamics.

# %%
fig_name='figures/richness_count_'+Initial_type+'.pdf'
print (fig_name)
fig=Model_plot._plot_richness_distribution(fig_name)
# Out:
# figures/richness_count_steady.pdf
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Mean and vaiance richness at differnt invasion steps

# %%
fig_name='figures/step_richness_'+Initial_type+'.pdf' 
print (fig_name)
fig=Model_plot._plot_richness_step(fig_name)
# Out:
# figures/step_richness_steady.pdf
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Richness and Consumed Power

# %%
fig_name='figures/richness_power_'+Initial_type+'.pdf'
print (fig_name)
fig=Model_plot._plot_richness_power(fig_name)
# Out:
# figures/richness_power_steady.pdf
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:932: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Steps and Consumed Power

# %%
fig_name='figures/step_power_'+Initial_type+'.pdf'  
fig=Model_plot._plot_step_power(fig_name)
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:932: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Community augmentation, richness and consumed power

# %%
fig_name='figures/richness_augmentation_power_'+Initial_type+'.pdf'  
fig=Model_plot._plot_community_richness(fig_name)

# %% [markdown]
# ### Community augmentaion and consumed power

# %%
fig_name='figures/step_augmentation_power_'+Initial_type+'.pdf' 
fig=Model_plot._plot_community_step(fig_name)

# %% [markdown]
# ## Large maintance costs(10 times larger)

# %%
Initial_type='steady_initial'
condition='_large_cost'
data_Community_augmentation='simulation_data/Richness_augmentation_p0.1_large_m_2018_05_09-10-05_correction.csv'
data_name=data_Community_augmentation
Model_plot=Invasion_plot([data_name])

# %% [markdown]
# ### Richness and Consumed Power

# %%
fig_name='figures/richness_power_'+Initial_type+condition+'.pdf'
print (fig_name)
fig=Model_plot._plot_richness_power(fig_name)
# Out:
# figures/richness_power_steady_initial_large_cost.pdf
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ## Large niche overlap

# %%
Initial_type='steady_initial'
condition='_large_niche'
data_Community_augmentation='simulation_data/Richness_augmentation_p0.5_niche_overlap_2018_05_08-22-16_correction.csv'
data_name=data_Community_augmentation
Model_plot=Invasion_plot([data_name])

# %% [markdown]
# ### Community augmentation, richness and consumed power

# %%
fig_name='figures/step_augmentation_power_'+Initial_type+condition+'.pdf' 
fig=Model_plot._plot_community_richness(fig_name)

# %% [markdown]
# ### Community augmentation, step and consumed power

# %%
fig_name='figures/step_augmentation_power_'+Initial_type+condition+'.pdf' 
fig=Model_plot._plot_community_step(fig_name, xright=100)

# %% [markdown]
# ## Large steps

# %%
Initial_type='steady_initial'
condition='_large_steps'
data_Community_augmentation='simulation_data/Richness_augmentation_p0.1_large_step_2018_05_09-22-53_correction.csv'
data_name=data_Community_augmentation
Model_plot=Invasion_plot([data_name])
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# ### Community augmentation, richness and consumed power

# %%
fig_name='figures/step_augmentation_power_'+Initial_type+condition+'.pdf' 
fig=Model_plot._plot_community_richness(fig_name)

# %% [markdown]
# ### Community augmentation, step and consumed power

# %%
fig_name='figures/step_augmentation_power_'+Initial_type+condition+'.pdf' 
fig=Model_plot._plot_community_step(fig_name, xright=1000)

# %% [markdown]
# ### Richness distribution

# %%
fig_name='figures/richness_count_'+Initial_type+condition+'.pdf'
fig=Model_plot._plot_richness_distribution(fig_name)
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Mean and vaiance richness at differnt invasion steps

# %%
fig_name='figures/step_richness_'+Initial_type+condition+'.pdf' 
fig=Model_plot._plot_richness_step(fig_name)
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Richness and Consumed Power

# %%
fig_name='figures/richness_power_'+Initial_type+condition+'.pdf'
fig=Model_plot._plot_richness_power(fig_name)
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Steps and Consumed Power

# %%
fig_name='figures/step_power_'+Initial_type+condition+'.pdf'  
fig=Model_plot._plot_step_power(fig_name)
# Out:
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /Users/wenpingcui/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/categorical.py:932: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
